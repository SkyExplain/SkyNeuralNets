# %%
import healpy as hp
import numpy as np
import tensorflow as tf, sys, os
from tensorflow.keras import layers, models, regularizers
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.ndimage import gaussian_filter
tf.keras.backend.clear_session() #clear any previous models

plots_directory = "/mnt/lustre/scratch/nlsas/home/csic/eoy/ioj/SkyNeuralNets/plots/"
data_directory = "/mnt/lustre/scratch/nlsas/home/csic/eoy/ioj/SkySimulation/data/simulated_data/"
os.chdir(data_directory)
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1' #disable GPU
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  #suppress TF warnings
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /mnt/lustre/scratch/nlsas/home/csic/eoy/ioj/SkySimulation/data/simulated_data

# %%
print("TF:", tf.__version__)
print("Python:", sys.version.split()[0])
print("LD_LIBRARY_PATH:", os.environ.get("LD_LIBRARY_PATH"))
# Out:
# TF: 2.10.1
# Python: 3.10.15
# LD_LIBRARY_PATH: /mnt/netapp1/Optcesga_FT2_RHEL7/2020/gentoo/22072020/usr/gr/lib64

# %%
from SkyNeuralNets import read_map
#Read the data
path_lcdm = "./simulated_maps/"
map_temp_data = read_map(path_lcdm + 'cmb_map_0.fits')

#Visualize the map
nside = hp.npix2nside(len(map_temp_data))
#nside = 64
print(f"NSIDE: {nside}")
# Out:
# Filename: ./simulated_maps/cmb_map_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# NSIDE: 256

# %%
def read_all_maps(path_lcdm, path_feature, n_maps=100):
    maps = []
    labels = []
    
    #LCDM maps
    for i in range(n_maps):
        map_lcdm = read_map(f"{path_lcdm}cmb_map_{i}.fits")
        maps.append(map_lcdm)
        labels.append(0)  #lcdm
    
    #Feature maps
    for i in range(n_maps):
        map_feature = read_map(f"{path_feature}cmb_map_feature_{i}.fits")
        maps.append(map_feature)
        labels.append(1)  #feature
    
    maps = np.array(maps).astype(np.float32)[..., None]  #Add channel dimension
    labels = np.array(labels).astype(np.int32)
    #print(labels)
    return maps, labels

# %%
def map_to_image(hp_map, xsize=256):
    #Validate that map has correct length
    hp_map = np.asarray(hp_map, dtype=np.float64)
    try:
        nside = hp.get_nside(hp_map)
    except Exception as e:
        print("Invalid map shape:", hp_map.shape)
        raise e
    img = hp.cartview(hp_map, xsize=xsize, return_projected_map=True, title="", cbar=False)
    plt.close()
    return img

# %%
path_feature = "./simulated_maps/"
x_raw, y_raw = read_all_maps(path_lcdm, path_feature, n_maps=225) #0: lcdm, 1:feature
# Out:
# Filename: ./simulated_maps/cmb_map_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_12.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_13.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_14.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_15.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_18.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_19.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_20.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_21.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_22.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_23.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_24.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_25.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_26.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_27.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_28.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_29.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_30.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_31.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_32.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_33.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_34.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_35.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_36.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_37.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_38.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_39.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_40.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_41.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_42.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_43.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_44.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_45.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_46.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_47.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_48.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_49.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_50.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_51.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_52.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_53.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_54.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_55.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_56.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_57.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_58.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_59.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_60.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_61.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_62.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_63.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_64.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_65.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_66.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_67.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_68.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_69.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_70.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_71.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_72.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_73.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_74.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_75.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_76.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_77.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_78.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_79.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_80.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_81.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_82.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_83.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_84.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_85.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_86.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_87.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_88.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_89.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_90.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_91.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_92.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_93.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_94.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_95.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_96.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_97.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_98.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_99.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_100.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_101.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_102.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_103.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_104.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_105.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_106.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_107.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_108.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_109.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_110.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_111.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_112.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_113.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_114.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_115.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_116.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_117.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_118.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_119.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_120.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_121.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_122.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_123.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_124.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_125.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_126.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_127.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_128.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_129.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_130.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_131.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_132.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_133.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_134.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_135.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_136.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_137.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_138.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_139.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_140.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_141.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_142.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_143.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_144.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_145.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_146.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_147.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_148.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_149.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_150.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_151.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_152.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_153.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_154.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_155.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_156.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_157.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_158.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_159.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_160.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_161.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_162.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_163.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_164.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_165.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_166.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_167.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_168.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_169.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_170.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_171.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_172.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_173.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_174.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_175.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_176.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_177.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_178.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_179.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_180.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ...
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_167.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_168.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_169.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_170.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_171.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_172.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_173.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_174.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_175.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_176.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_177.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_178.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_179.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_180.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_181.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_182.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_183.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_184.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_185.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_186.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_187.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_188.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_189.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_190.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_191.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_192.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_193.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_194.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_195.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_196.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_197.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_198.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_199.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_200.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_201.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_202.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_203.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_204.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_205.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_206.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_207.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_208.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_209.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_210.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_211.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_212.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_213.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_214.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_215.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_216.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_217.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_218.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_219.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_220.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_221.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_222.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_223.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_224.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )

# %%
x_raw_new = np.array(x_raw).squeeze()

# %%
imgs = np.array([map_to_image(m) for m in x_raw_new])
if imgs.ndim == 3:
    imgs = imgs[..., np.newaxis]  #add channel dimension

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(imgs, y_raw, test_size=0.2, random_state=15)
X_test, X_val, y_test, y_val = train_test_split(imgs, y_raw, test_size=0.2, random_state=15)

# %%
np.shape(X_train)
# Out:
# (360, 128, 256, 1)

# %%
#Check the class weights to handle imbalance
from sklearn.utils import class_weight
print(f"Training set Class 1 ratio: {y_train.mean():.4f}")
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(y_train),
    y=y_train
)
# Out:
# Training set Class 1 ratio: 0.4889

# %%
from sklearn.decomposition import PCA
def apply_pca_subtraction(X_train, X_val, X_test, y_train, n_components=100):
    """
    Uses PCA to learn the dominant "noise" modes from the Class 0 maps
    and subtracts this learned noise from all maps.
    
    n_components: Number of principal components (noise modes) to learn.
                  You can also use a float (e.g., 0.999) to keep
                  components explaining 99.9% of the variance.
    """
    print(f"Starting PCA Noise Subtraction with n_components={n_components}...")
    
    #1. Get original shape and flatten data
    orig_shape = X_train.shape[1:] #(H, W, 1)
    n_features = np.prod(orig_shape) #H*W*1
    
    X_train_flat = X_train.reshape(X_train.shape[0], -1)
    X_val_flat = X_val.reshape(X_val.shape[0], -1)
    X_test_flat = X_test.reshape(X_test.shape[0], -1)
    
    #2. Isolate "noise" maps (Class 0) from X_train
    noise_indices = (y_train == 0)
    X_noise_flat = X_train_flat[noise_indices]
    
    if X_noise_flat.shape[0] == 0:
        print("Error: No Class 0 maps found in y_train. Cannot fit PCA.")
        return X_train, X_val, X_test

    print(f"  Fitting PCA on {X_noise_flat.shape[0]} 'noise' maps...")
    
    #3. Fit PCA *only* on the noise maps
    pca = PCA(n_components=n_components, whiten=False)
    pca.fit(X_noise_flat)
    
    print(f"  PCA fitted. Explained variance with {pca.n_components_} components: {np.sum(pca.explained_variance_ratio_):.4f}")
    
    #4. Transform and inverse-transform all maps to get the "noise" part
    print("  Transforming and subtracting noise from all datasets...")
    
    #Project data onto noise basis and reconstruct the noise part
    X_train_noise_part = pca.inverse_transform(pca.transform(X_train_flat))
    X_val_noise_part = pca.inverse_transform(pca.transform(X_val_flat))
    X_test_noise_part = pca.inverse_transform(pca.transform(X_test_flat))
    
    #5. Subtract the noise part to get the signal (residual)
    X_train_signal_part_flat = X_train_flat - X_train_noise_part
    X_val_signal_part_flat = X_val_flat - X_val_noise_part
    X_test_signal_part_flat = X_test_flat - X_test_noise_part
    
    #6. Reshape signal part back to original map shape
    X_train_pca = X_train_signal_part_flat.reshape(X_train.shape).astype(np.float32)
    X_val_pca = X_val_signal_part_flat.reshape(X_val.shape).astype(np.float32)
    X_test_pca = X_test_signal_part_flat.reshape(X_test.shape).astype(np.float32)
    
    print("PCA Noise Subtraction complete.")
    return X_train_pca, X_val_pca, X_test_pca

# %%
X_train_pca, X_val_pca, X_test_pca = apply_pca_subtraction(
    X_train, X_val, X_test, y_train, n_components=100)
# Out:
# Starting PCA Noise Subtraction with n_components=100...
#   Fitting PCA on 184 'noise' maps...
#   PCA fitted. Explained variance with 100 components: 1.0000
#   Transforming and subtracting noise from all datasets...
# PCA Noise Subtraction complete.

# %%
#======== Define Model ========
model = models.Sequential([
    layers.Input(shape=X_train.shape[1:]),        

    layers.Conv2D(32, (3,3), padding="same", use_bias=False),
    layers.BatchNormalization(), layers.ReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), padding="same", use_bias=False),
    layers.BatchNormalization(), layers.ReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), padding="same", use_bias=False),
    layers.BatchNormalization(), layers.ReLU(),

    layers.GlobalAveragePooling2D(),             
    layers.Dropout(0.2),
    layers.Dense(64, activation="relu",
                 kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.2),
    layers.Dense(1, activation="sigmoid"),
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4, clipnorm=1.0),
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)
model.summary(110)

cb = [
  tf.keras.callbacks.EarlyStopping(monitor="val_auc", patience=200, mode="max", restore_best_weights=True),
  tf.keras.callbacks.ReduceLROnPlateau(monitor="val_auc", factor=0.5, patience=200, mode="max", min_lr=1e-6)
]
# Out:
# Model: "sequential"
# ______________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                                Param #
# ==============================================================================================================
#  conv2d (Conv2D)                                 (None, 128, 256, 32)                        288
#
#  batch_normalization (BatchNormalization)        (None, 128, 256, 32)                        128
#
#  re_lu (ReLU)                                    (None, 128, 256, 32)                        0
#
#  max_pooling2d (MaxPooling2D)                    (None, 64, 128, 32)                         0
#
#  conv2d_1 (Conv2D)                               (None, 64, 128, 64)                         18432
#
#  batch_normalization_1 (BatchNormalization)      (None, 64, 128, 64)                         256
#
#  re_lu_1 (ReLU)                                  (None, 64, 128, 64)                         0
#
#  max_pooling2d_1 (MaxPooling2D)                  (None, 32, 64, 64)                          0
#
#  conv2d_2 (Conv2D)                               (None, 32, 64, 128)                         73728
#
#  batch_normalization_2 (BatchNormalization)      (None, 32, 64, 128)                         512
#
#  re_lu_2 (ReLU)                                  (None, 32, 64, 128)                         0
#
#  global_average_pooling2d (GlobalAveragePooling2  (None, 128)                                0
#  D)
#
#  dropout (Dropout)                               (None, 128)                                 0
#
#  dense (Dense)                                   (None, 64)                                  8256
#
#  dropout_1 (Dropout)                             (None, 64)                                  0
#
#  dense_1 (Dense)                                 (None, 1)                                   65
#
# ==============================================================================================================
# Total params: 101,665
# Trainable params: 101,217
# Non-trainable params: 448
# ______________________________________________________________________________________________________________

# %%
history = model.fit(
    X_train_pca,
    y_train, 
    epochs=500, 
    batch_size=32, 
    validation_data=(X_val_pca, y_val),
    callbacks=cb,
)
# Out:
# Epoch 1/500
# 12/12 [==============================] - 19s 718ms/step - loss: 0.4214 - accuracy: 0.8389 - auc: 0.9248 - val_loss: 0.7012 - val_accuracy: 0.4556 - val_auc: 0.9184 - lr: 1.0000e-04
# Epoch 2/500
# 12/12 [==============================] - 7s 574ms/step - loss: 0.2385 - accuracy: 0.9417 - auc: 0.9855 - val_loss: 0.7048 - val_accuracy: 0.4556 - val_auc: 0.8980 - lr: 1.0000e-04
# Epoch 3/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.1670 - accuracy: 0.9694 - auc: 0.9922 - val_loss: 0.7049 - val_accuracy: 0.4556 - val_auc: 0.9184 - lr: 1.0000e-04
# Epoch 4/500
# 12/12 [==============================] - 7s 565ms/step - loss: 0.1337 - accuracy: 0.9750 - auc: 0.9987 - val_loss: 0.6987 - val_accuracy: 0.4556 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 5/500
# 12/12 [==============================] - 7s 565ms/step - loss: 0.1244 - accuracy: 0.9806 - auc: 0.9967 - val_loss: 0.6875 - val_accuracy: 0.8556 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 6/500
# 12/12 [==============================] - 7s 555ms/step - loss: 0.0803 - accuracy: 0.9861 - auc: 0.9998 - val_loss: 0.6776 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 7/500
# 12/12 [==============================] - 7s 546ms/step - loss: 0.0815 - accuracy: 0.9861 - auc: 1.0000 - val_loss: 0.6782 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 8/500
# 12/12 [==============================] - 7s 555ms/step - loss: 0.0796 - accuracy: 0.9917 - auc: 0.9990 - val_loss: 0.6887 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 9/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0542 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.7074 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 10/500
# 12/12 [==============================] - 7s 565ms/step - loss: 0.0759 - accuracy: 0.9833 - auc: 0.9994 - val_loss: 0.7542 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 11/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0436 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.8009 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 12/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0511 - accuracy: 0.9917 - auc: 1.0000 - val_loss: 0.8555 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 13/500
# 12/12 [==============================] - 7s 580ms/step - loss: 0.0567 - accuracy: 0.9889 - auc: 0.9990 - val_loss: 0.9392 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 14/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0335 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 1.0179 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 15/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0410 - accuracy: 0.9944 - auc: 1.0000 - val_loss: 1.0807 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 16/500
# 12/12 [==============================] - 7s 563ms/step - loss: 0.0561 - accuracy: 0.9889 - auc: 0.9989 - val_loss: 1.1426 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 17/500
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0276 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 1.1888 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 18/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0241 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 1.2138 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 19/500
# 12/12 [==============================] - 7s 556ms/step - loss: 0.0257 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 1.2127 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 20/500
# 12/12 [==============================] - 7s 555ms/step - loss: 0.0265 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 1.1801 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 21/500
# 12/12 [==============================] - 7s 548ms/step - loss: 0.0337 - accuracy: 0.9944 - auc: 1.0000 - val_loss: 1.1621 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 22/500
# 12/12 [==============================] - 7s 563ms/step - loss: 0.0242 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 1.1871 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 23/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0238 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 1.1280 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 24/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0230 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 1.1157 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 25/500
# 12/12 [==============================] - 7s 565ms/step - loss: 0.0198 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 1.0041 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 26/500
# 12/12 [==============================] - 7s 555ms/step - loss: 0.0212 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.7919 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 27/500
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0192 - accuracy: 0.9944 - auc: 1.0000 - val_loss: 0.7313 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 28/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0212 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.6615 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 29/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0363 - accuracy: 0.9972 - auc: 0.9974 - val_loss: 0.4792 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 30/500
# 12/12 [==============================] - 7s 565ms/step - loss: 0.0231 - accuracy: 0.9944 - auc: 1.0000 - val_loss: 0.4041 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 31/500
# 12/12 [==============================] - 7s 546ms/step - loss: 0.0254 - accuracy: 0.9944 - auc: 1.0000 - val_loss: 0.3495 - val_accuracy: 0.5444 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 32/500
# 12/12 [==============================] - 7s 563ms/step - loss: 0.0153 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2384 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 33/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0145 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1466 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 34/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0156 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0966 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 35/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0162 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0762 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 36/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0179 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0570 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 37/500
# 12/12 [==============================] - 7s 565ms/step - loss: 0.0125 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0477 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 38/500
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0153 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0433 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 39/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0345 - accuracy: 0.9861 - auc: 0.9999 - val_loss: 0.0373 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 40/500
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0123 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9889 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 41/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0160 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9889 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 42/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0139 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9889 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 43/500
# 12/12 [==============================] - 7s 565ms/step - loss: 0.0427 - accuracy: 0.9889 - auc: 0.9992 - val_loss: 0.0305 - val_accuracy: 0.9889 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 44/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0122 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9889 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 45/500
# 12/12 [==============================] - 7s 556ms/step - loss: 0.0156 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9889 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 46/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0123 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0214 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 47/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0121 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0208 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 48/500
# 12/12 [==============================] - 7s 556ms/step - loss: 0.0119 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0189 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 49/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0116 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0165 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 50/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0202 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0140 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 51/500
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0108 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 52/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0193 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0109 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 53/500
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0114 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 54/500
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0119 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 55/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0353 - accuracy: 0.9861 - auc: 0.9999 - val_loss: 0.0094 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 56/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0116 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 57/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0283 - accuracy: 0.9944 - auc: 0.9997 - val_loss: 0.0092 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 58/500
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0167 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 59/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0113 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 60/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0106 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 61/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0117 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 62/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0113 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 63/500
# 12/12 [==============================] - 7s 581ms/step - loss: 0.0110 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 64/500
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0111 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 65/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0096 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 66/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0162 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 67/500
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0110 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 68/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0123 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 69/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0180 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 70/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0128 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 71/500
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0099 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 72/500
# 12/12 [==============================] - 7s 581ms/step - loss: 0.0102 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 73/500
# 12/12 [==============================] - 7s 581ms/step - loss: 0.0097 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 74/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0095 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 75/500
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0101 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 76/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0095 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 77/500
# 12/12 [==============================] - 7s 573ms/step - loss: 0.0261 - accuracy: 0.9917 - auc: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 78/500
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0298 - accuracy: 0.9917 - auc: 0.9997 - val_loss: 0.0087 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 79/500
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0098 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 80/500
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0095 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 81/500
# 12/12 [==============================] - 7s 565ms/step - loss: 0.0091 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 82/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0095 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 83/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0177 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 84/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0097 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 85/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0108 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 86/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0101 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 87/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0114 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 88/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0104 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 89/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0136 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 90/500
# 12/12 [==============================] - 7s 602ms/step - loss: 0.0098 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 91/500
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0091 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 92/500
# 12/12 [==============================] - 7s 601ms/step - loss: 0.0138 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 93/500
# 12/12 [==============================] - 7s 618ms/step - loss: 0.0091 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 94/500
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0154 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 95/500
# 12/12 [==============================] - 7s 610ms/step - loss: 0.0124 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 96/500
# 12/12 [==============================] - 7s 618ms/step - loss: 0.0090 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 97/500
# 12/12 [==============================] - 7s 601ms/step - loss: 0.0090 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 98/500
# 12/12 [==============================] - 7s 618ms/step - loss: 0.0088 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 99/500
# 12/12 [==============================] - 7s 601ms/step - loss: 0.0100 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 100/500
# 12/12 [==============================] - 7s 610ms/step - loss: 0.0104 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 101/500
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0086 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 102/500
# 12/12 [==============================] - 7s 608ms/step - loss: 0.0113 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 103/500
# 12/12 [==============================] - 7s 602ms/step - loss: 0.0093 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 104/500
# 12/12 [==============================] - 7s 619ms/step - loss: 0.0090 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 105/500
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0088 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 106/500
# 12/12 [==============================] - 7s 608ms/step - loss: 0.0087 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 107/500
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0087 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 108/500
# 12/12 [==============================] - 7s 608ms/step - loss: 0.0087 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 109/500
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0108 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 110/500
# 12/12 [==============================] - 7s 610ms/step - loss: 0.0101 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 111/500
# 12/12 [==============================] - 7s 627ms/step - loss: 0.0111 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 112/500
# 12/12 [==============================] - 7s 602ms/step - loss: 0.0102 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 113/500
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0093 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 114/500
# 12/12 [==============================] - 7s 610ms/step - loss: 0.0088 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 115/500
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0094 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 116/500
# 12/12 [==============================] - 7s 608ms/step - loss: 0.0085 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 117/500
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0441 - accuracy: 0.9944 - auc: 0.9959 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 118/500
# 12/12 [==============================] - 7s 601ms/step - loss: 0.0088 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 119/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0094 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 120/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0115 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 121/500
# 12/12 [==============================] - 7s 608ms/step - loss: 0.0101 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 122/500
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0093 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 123/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0092 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 124/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0093 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 125/500
# 12/12 [==============================] - 7s 598ms/step - loss: 0.0089 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 126/500
# 12/12 [==============================] - 7s 584ms/step - loss: 0.0083 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 127/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0098 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 128/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0090 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 129/500
# 12/12 [==============================] - 7s 591ms/step - loss: 0.0085 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 130/500
# 12/12 [==============================] - 7s 610ms/step - loss: 0.0083 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 131/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0082 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 132/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0083 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 133/500
# 12/12 [==============================] - 7s 601ms/step - loss: 0.0082 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 134/500
# 12/12 [==============================] - 7s 590ms/step - loss: 0.0127 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 135/500
# 12/12 [==============================] - 7s 591ms/step - loss: 0.0116 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 136/500
# 12/12 [==============================] - 7s 583ms/step - loss: 0.0083 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 137/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0136 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 138/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0084 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 139/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0095 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 140/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0082 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 141/500
# 12/12 [==============================] - 7s 591ms/step - loss: 0.0085 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 142/500
# 12/12 [==============================] - 7s 591ms/step - loss: 0.0097 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 143/500
# 12/12 [==============================] - 7s 591ms/step - loss: 0.0083 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 144/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0095 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 145/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0139 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 146/500
# 12/12 [==============================] - 7s 580ms/step - loss: 0.0096 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 147/500
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0191 - accuracy: 0.9944 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 148/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0090 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 149/500
# 12/12 [==============================] - 7s 601ms/step - loss: 0.0088 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 150/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0081 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 151/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0083 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 152/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0081 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 153/500
# 12/12 [==============================] - 7s 583ms/step - loss: 0.0081 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 154/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0081 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 155/500
# 12/12 [==============================] - 7s 583ms/step - loss: 0.0079 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 156/500
# 12/12 [==============================] - 7s 591ms/step - loss: 0.0080 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 157/500
# 12/12 [==============================] - 7s 591ms/step - loss: 0.0079 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 158/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0082 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 159/500
# 12/12 [==============================] - 7s 591ms/step - loss: 0.0081 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 160/500
# 12/12 [==============================] - 7s 590ms/step - loss: 0.0105 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 161/500
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0080 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 162/500
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0078 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 163/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0081 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 164/500
# 12/12 [==============================] - 7s 583ms/step - loss: 0.0085 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 165/500
# 12/12 [==============================] - 7s 565ms/step - loss: 0.0107 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 166/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0091 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 167/500
# 12/12 [==============================] - 7s 590ms/step - loss: 0.0080 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 168/500
# 12/12 [==============================] - 7s 591ms/step - loss: 0.0078 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 169/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0077 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 170/500
# 12/12 [==============================] - 7s 583ms/step - loss: 0.0077 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 171/500
# 12/12 [==============================] - 7s 591ms/step - loss: 0.0090 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 172/500
# 12/12 [==============================] - 7s 563ms/step - loss: 0.0085 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 173/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0080 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 174/500
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0084 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 175/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0104 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 176/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0103 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 177/500
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0098 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 178/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0096 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 179/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0079 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 180/500
# 12/12 [==============================] - 7s 601ms/step - loss: 0.0077 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 181/500
# 12/12 [==============================] - 7s 601ms/step - loss: 0.0078 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 182/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0157 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 183/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0079 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 184/500
# 12/12 [==============================] - 7s 593ms/step - loss: 0.0081 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 185/500
# 12/12 [==============================] - 7s 601ms/step - loss: 0.0082 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 186/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0076 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 187/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0081 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 188/500
# 12/12 [==============================] - 7s 618ms/step - loss: 0.0078 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 189/500
# 12/12 [==============================] - 7s 617ms/step - loss: 0.0090 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 190/500
# 12/12 [==============================] - 8s 627ms/step - loss: 0.0077 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 191/500
# 12/12 [==============================] - 7s 619ms/step - loss: 0.0086 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 192/500
# 12/12 [==============================] - 7s 618ms/step - loss: 0.0077 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 193/500
# 12/12 [==============================] - 7s 610ms/step - loss: 0.0075 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 194/500
# 12/12 [==============================] - 7s 609ms/step - loss: 0.0076 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 195/500
# 12/12 [==============================] - 7s 618ms/step - loss: 0.0078 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 196/500
# 12/12 [==============================] - 7s 618ms/step - loss: 0.0082 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 197/500
# 12/12 [==============================] - 7s 627ms/step - loss: 0.0075 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 198/500
# 12/12 [==============================] - 7s 627ms/step - loss: 0.0073 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 199/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0074 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 200/500
# 12/12 [==============================] - 7s 608ms/step - loss: 0.0075 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 201/500
# 12/12 [==============================] - 7s 592ms/step - loss: 0.0073 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 202/500
# 12/12 [==============================] - 7s 599ms/step - loss: 0.0074 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 203/500
# 12/12 [==============================] - 7s 600ms/step - loss: 0.0073 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 204/500
# 12/12 [==============================] - 7s 605ms/step - loss: 0.0073 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04

# %%
test_loss, test_acc, test_auc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 12/12 [==============================] - 1s 111ms/step - loss: 13.5867 - accuracy: 0.4889 - auc: 0.5000
# Test accuracy: 0.4889

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["accuracy"], label="training")
plt.plot(history.history["val_accuracy"], label="validation")
plt.grid()
plt.yscale("log")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["loss"], label="training")
plt.plot(history.history["val_loss"], label="validation")
plt.grid()
plt.yscale("log")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
#sanity check
print(np.mean(X_train_pca), np.std(X_train_pca))   #mean~0, st.dev~1
print(np.mean(X_test_pca),  np.std(X_test_pca))    #should be close to train
# Out:
# 6.8170186e-05 0.0072769234
# 6.8170186e-05 0.0072769234

# %%
# Get model probabilities
probs = model.predict(X_test_pca, batch_size=64).ravel()
# Out:
# 6/6 [==============================] - 1s 241ms/step

# %%
#Check the class balance, do we have a 50/50 split?
print("class balance test:", (y_test==1).mean())
# Out:
# class balance test: 0.4888888888888889

# %%
#Let's check the ranges of probabilities, why is the CNN classfiying everything as LCDM?
print("min/max/mean probs:", probs.min(), probs.max(), probs.mean())
# Out:
# min/max/mean probs: 0.46531555 0.48617747 0.46979904

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix, accuracy_score, ConfusionMatrixDisplay

#Find optimal threshold from ROC
fpr, tpr, thr = roc_curve(y_test, probs)
t_opt = thr[np.argmax(tpr - fpr)]
print("AUC:", auc(fpr, tpr), "t*:", t_opt)

#Apply the new threshold to get predictions, Youden's index https://en.wikipedia.org/wiki/Youden%27s_J_statistic
pred = (probs >= t_opt).astype(int)
# Out:
# AUC: 1.0 t*: 0.46707398

# %%
#Accuracy
acc = accuracy_score(y_test, pred)
print("Accuracy:", acc)

#Confusion matrix
cm = confusion_matrix(y_test, pred, labels=[0, 1])
print("Confusion matrix:\n", cm)
# Out:
# Accuracy: 1.0
# Confusion matrix:
#  [[184   0]
#  [  0 176]]

# %%
#-----------------------------------------------------------------------------------------------------------
#Performance: correct & incorrect  predictions
#-----------------------------------------------------------------------------------------------------------
#True positive: LCDM=0, Feature=1
true_LCDM = []
true_MoG = []
false_LCDM = []
false_MoG = []

for pred, true in zip(pred, y_test):
    if pred==0 and true==0:
        true_LCDM.append(1)
    if pred==1 and true==1:
        true_MoG.append(1)
    if pred==0 and true==1:
        false_LCDM.append(1)
    if pred==1 and true==0:
        false_MoG.append(1)
lenghts=[len(true_LCDM),len(true_MoG),len(false_LCDM),len(false_MoG)]

print('     ','LCDM','FT')
print('True ',len(true_LCDM)/sum(lenghts),len(true_MoG)/sum(lenghts))
print('False',len(false_LCDM)/sum(lenghts),len(false_MoG)/sum(lenghts))
print('--------------')
print("Correct prediction: ",(len(true_LCDM)+len(true_MoG))/sum(lenghts))
print("Wrong prediction  : ",(len(false_LCDM)+len(false_MoG))/sum(lenghts))
# Out:
#       LCDM FT
# True  0.5111111111111111 0.4888888888888889
# False 0.0 0.0
# --------------
# Correct prediction:  1.0
# Wrong prediction  :  0.0

# %%
#Plot confusion matrix
cm_prob = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
disp = ConfusionMatrixDisplay(confusion_matrix=cm_prob, display_labels=["ΛCDM", "Feature"])
disp.plot(cmap="Blues", values_format='.3f')
plt.title(f"Confusion Matrix (Accuracy={acc:.3f})")
#plt.savefig("/mnt/lustre/scratch/nlsas/home/csic/eoy/ioj/SkyNeuralNets/plots/confusion_matrix.png", dpi=300)
plt.show()

# %%
#Plot the ROC curve with Youden index (https://en.wikipedia.org/wiki/Youden%27s_J_statistic#/media/File:ROC_Curve_T1D_Validation,_top5_r2filtered.svg)
from sklearn.metrics import auc
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, color="blue", lw=2, label=f"ROC curve (AUC = {roc_auc:.3f})")
plt.plot([0, 1], [0, 1], color="gray", lw=1, linestyle="--")

t_star_idx = np.argmax(tpr - fpr)
t_star = thr[t_star_idx]

#Mark t* point
plt.scatter(fpr[t_star_idx], tpr[t_star_idx], color="red", s=80, zorder=5,
            label=f"t* = {t_star:.4f}")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC)")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
