# %%
import healpy as hp
import numpy as np
import tensorflow as tf, sys, os
from tensorflow.keras import layers, models, regularizers
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.ndimage import gaussian_filter
import faulthandler, sys, os
faulthandler.enable(all_threads=True)
print("PID:", os.getpid())
print("Python:", sys.version)

tf.keras.backend.clear_session() #clear any previous models

plots_directory = "/mnt/lustre/scratch/nlsas/home/csic/eoy/ioj/SkyNeuralNets/plots/"
data_directory = "/mnt/netapp1/Store_CSIC/home/csic/eoy/ioj/SkySimulation/data/simulated_data/"
os.chdir(data_directory)
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1' #disable GPU
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  #suppress TF warnings
print("Current working directory:", os.getcwd())
# Out:
# 2025-12-15 18:47:15.461097: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-15 18:47:34.387457: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-15 18:47:39.849454: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /mnt/netapp1/Optcesga_FT2_RHEL7/2020/gentoo/22072020/usr/gr/lib64
# 2025-12-15 18:47:39.849491: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2025-12-15 18:47:42.387205: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-15 18:48:23.817955: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /mnt/netapp1/Optcesga_FT2_RHEL7/2020/gentoo/22072020/usr/gr/lib64
# 2025-12-15 18:48:23.818198: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /mnt/netapp1/Optcesga_FT2_RHEL7/2020/gentoo/22072020/usr/gr/lib64
# 2025-12-15 18:48:23.818207: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# PID: 2202279
# Python: 3.10.15 | packaged by conda-forge | (main, Oct 16 2024, 01:24:24) [GCC 13.3.0]
# Current working directory: /mnt/netapp1/Store_CSIC/home/csic/eoy/ioj/SkySimulation/data/simulated_data

# %%
print("TF:", tf.__version__)
print("Python:", sys.version.split()[0])
print("LD_LIBRARY_PATH:", os.environ.get("LD_LIBRARY_PATH"))
# Out:
# TF: 2.10.1
# Python: 3.10.15
# LD_LIBRARY_PATH: /mnt/netapp1/Optcesga_FT2_RHEL7/2020/gentoo/22072020/usr/gr/lib64

# %%
from SkyNeuralNets import read_map
#Read the data
path_lcdm = "./simulated_maps/polarization/"
map_temp_data = read_map(path_lcdm + 'cmb_pol_map_U_0.fits')

#Visualize the map
nside = hp.npix2nside(len(map_temp_data))
#nside = 64
print(f"NSIDE: {nside}")
# Out:
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# NSIDE: 256

# %%
def read_all_maps(path_lcdm, path_feature, n_maps=100, polarization=False):
    """Reads all maps from specified directories and returns them as numpy arrays.
    Args:
        path_lcdm (str): Path to the directory containing LCDM maps.
        path_feature (str): Path to the directory containing feature maps.
        n_maps (int): Number of maps to read from each directory.
    Returns:
        tuple: A tuple containing two numpy arrays - maps and labels.
    """

    maps = []
    labels = []
    
    for i in range(n_maps):
            if polarization:
                lcdm_T = read_map(os.path.join(path_lcdm, f"cmb_pol_map_T_{i}.fits"))
                lcdm_Q = read_map(os.path.join(path_lcdm, f"cmb_pol_map_Q_{i}.fits"))
                lcdm_U = read_map(os.path.join(path_lcdm, f"cmb_pol_map_U_{i}.fits"))
                maps.append(np.stack([lcdm_T, lcdm_Q, lcdm_U], axis=-1))
                labels.append(0)

                feat_T = read_map(os.path.join(path_feature, f"cmb_pol_map_T_feature_{i}.fits"))
                feat_Q = read_map(os.path.join(path_feature, f"cmb_pol_map_Q_feature_{i}.fits"))
                feat_U = read_map(os.path.join(path_feature, f"cmb_pol_map_U_feature_{i}.fits"))
                maps.append(np.stack([feat_T, feat_Q, feat_U], axis=-1))
                labels.append(1)
            else:
                lcdm_T = read_map(os.path.join(path_lcdm, f"cmb_pol_map_T_{i}.fits"))
                maps.append(lcdm_T)
                labels.append(0)

                feat_T = read_map(os.path.join(path_feature, f"cmb_pol_map_feature_T_{i}.fits"))
                maps.append(feat_T)
                labels.append(1)

    maps = np.asarray(maps, dtype=np.float32)
    if not polarization:
        maps = maps[..., None]  # (2N, H, W, 1)

    labels = np.asarray(labels, dtype=np.int32)
    return maps, labels

# %%
#from SkyNeuralNets import read_all_maps
path_feature = "./simulated_maps/polarization/"
x_raw, y_raw = read_all_maps(path_lcdm, path_feature, n_maps=224, polarization=True) #0: lcdm, 1:feature
# Out:
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_12.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_12.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_12.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_12.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_12.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_12.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_13.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_13.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_13.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_13.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_13.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_13.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_14.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_14.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_14.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_14.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_14.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_14.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_15.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_15.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_15.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_15.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_15.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_15.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_18.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_18.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_18.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_18.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_18.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_18.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_19.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_19.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_19.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_19.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_19.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_19.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_20.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_20.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_20.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_20.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_20.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_20.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_21.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_21.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_21.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_21.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_21.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_21.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_22.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_22.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_22.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_22.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_22.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_22.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_23.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_23.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_23.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_23.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_23.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_23.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_24.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_24.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_24.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_24.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_24.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_24.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_25.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_25.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_25.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_25.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_25.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_25.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_26.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_26.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_26.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_26.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_26.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_26.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_27.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_27.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_27.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_27.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_27.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
# ...
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_214.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_215.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_215.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_215.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_215.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_215.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_215.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_216.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_216.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_216.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_216.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_216.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_216.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_217.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_217.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_217.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_217.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_217.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_217.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_218.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_218.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_218.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_218.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_218.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_218.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_219.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_219.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_219.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_219.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_219.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_219.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_220.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_220.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_220.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_220.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_220.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_220.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_221.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_221.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_221.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_221.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_221.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_221.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_222.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_222.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_222.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_222.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_222.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_222.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_223.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_223.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_223.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_T_feature_223.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_Q_feature_223.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/polarization/cmb_pol_map_U_feature_223.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )

# %%
x_raw.shape
# Out:
# (448, 786432, 3)

# %% [markdown]
# ## indices match as follows:
# ```[n_map, n_components, T, Q, U], where 0 for T, 1 for Q, 2 for U ```

# %%
x_raw = x_raw[:,:,1]

# %%
from SkyNeuralNets import map_to_image
imgs = np.array([map_to_image(m) for m in x_raw])
if imgs.ndim == 3:
    imgs = imgs[..., np.newaxis]  #add channel dimension

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(imgs, y_raw, test_size=0.2, random_state=15)
X_test, X_val, y_test, y_val = train_test_split(imgs, y_raw, test_size=0.2, random_state=15)

# %%
np.shape(X_train)
# Out:
# (358, 128, 256, 1)

# %%
#Check the class weights to handle imbalance
from sklearn.utils import class_weight
print(f"Training set Class 1 ratio: {y_train.mean():.4f}")
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(y_train),
    y=y_train
)
# Out:
# Training set Class 1 ratio: 0.5000

# %%
from sklearn.decomposition import PCA
# ---- 1. Flatten data ----
orig_shape = X_train.shape[1:]   # e.g. (H, W, 1) or (H, W)
n_features = np.prod(orig_shape)

X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat   = X_val.reshape(X_val.shape[0], -1)
X_test_flat  = X_test.reshape(X_test.shape[0], -1)

# ---- 2. Fit PCA on noise (Class 0 in TRAIN only) ----
n_components = 100  # or 0.999 if you want variance fraction

noise_indices = (y_train == 0)
X_noise_flat  = X_train_flat[noise_indices]

if X_noise_flat.shape[0] == 0:
    raise RuntimeError("No Class 0 maps in y_train, cannot fit PCA")

print("Fitting PCA on noise maps...")
pca = PCA(n_components=n_components, whiten=False)
pca.fit(X_noise_flat)

print(f"Explained variance: {np.sum(pca.explained_variance_ratio_):.4f}")

# ---- 3. Subtract noise from all datasets ----
def subtract_noise(X_flat, pca_obj):
    noise_part = pca_obj.inverse_transform(pca_obj.transform(X_flat))
    signal_part = X_flat - noise_part
    return noise_part, signal_part

X_train_noise_flat, X_train_signal_flat = subtract_noise(X_train_flat, pca)
X_val_noise_flat,   X_val_signal_flat   = subtract_noise(X_val_flat,   pca)
X_test_noise_flat,  X_test_signal_flat  = subtract_noise(X_test_flat,  pca)

# Reshape back
X_train_pca = X_train_signal_flat.reshape(X_train.shape).astype(np.float32)
X_val_pca   = X_val_signal_flat.reshape(X_val.shape).astype(np.float32)
X_test_pca  = X_test_signal_flat.reshape(X_test.shape).astype(np.float32)

print("PCA noise subtraction done.")
# Out:
# Fitting PCA on noise maps...
# Explained variance: 1.0000
# PCA noise subtraction done.

# %%
#Check the statistics of the subtracted signal
print("Original Stats:  Mean={:.5f}, Std={:.5f}".format(np.mean(X_train), np.std(X_train)))
print("Signal Stats:    Mean={:.5e}, Std={:.5e}".format(np.mean(X_train_pca), np.std(X_train_pca)))
# Out:
# Original Stats:  Mean=-0.02383, Std=2.94300
# Signal Stats:    Mean=1.34597e-05, Std=1.27833e-03

# %% [markdown]
# ## Check this part for memory blow up

# %%
print(X_train_pca.shape, X_train_pca.dtype)
print(X_val_pca.shape, X_val_pca.dtype)

print("X_train size (GB):", X_train_pca.nbytes / 1024**3)
print("X_val size (GB):", X_val_pca.nbytes / 1024**3)
# Out:
# (358, 128, 256, 1) float32
# (90, 128, 256, 1) float32
# X_train size (GB): 0.043701171875
# X_val size (GB): 0.010986328125

# %%
#======== Define Model ========
model = models.Sequential([
    layers.Input(shape=X_train.shape[1:]),        

    layers.Conv2D(32, (3,3), padding="same", use_bias=False),
    layers.BatchNormalization(), layers.ReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), padding="same", use_bias=False),
    layers.BatchNormalization(), layers.ReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), padding="same", use_bias=False),
    layers.BatchNormalization(), layers.ReLU(),

    layers.GlobalAveragePooling2D(),             
    layers.Dropout(0.2),
    layers.Dense(64, activation="relu",
                 kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.2),
    layers.Dense(1, activation="sigmoid"),
])
# Out:
# 2025-12-15 19:02:09.444252: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /mnt/netapp1/Optcesga_FT2_RHEL7/2020/gentoo/22072020/usr/gr/lib64
# 2025-12-15 19:02:09.632890: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-15 19:02:09.728995: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (login209-18): /proc/driver/nvidia/version does not exist
# 2025-12-15 19:02:10.223165: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4, clipnorm=1.0),
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)
model.summary(110)

cb = [
  tf.keras.callbacks.EarlyStopping(monitor="val_auc", patience=300, mode="max", restore_best_weights=True),
  tf.keras.callbacks.ReduceLROnPlateau(monitor="val_auc", factor=0.5, patience=300, mode="max", min_lr=1e-6)
]
# Out:
# Model: "sequential"
# ______________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                                Param #
# ==============================================================================================================
#  conv2d (Conv2D)                                 (None, 128, 256, 32)                        288
#
#  batch_normalization (BatchNormalization)        (None, 128, 256, 32)                        128
#
#  re_lu (ReLU)                                    (None, 128, 256, 32)                        0
#
#  max_pooling2d (MaxPooling2D)                    (None, 64, 128, 32)                         0
#
#  conv2d_1 (Conv2D)                               (None, 64, 128, 64)                         18432
#
#  batch_normalization_1 (BatchNormalization)      (None, 64, 128, 64)                         256
#
#  re_lu_1 (ReLU)                                  (None, 64, 128, 64)                         0
#
#  max_pooling2d_1 (MaxPooling2D)                  (None, 32, 64, 64)                          0
#
#  conv2d_2 (Conv2D)                               (None, 32, 64, 128)                         73728
#
#  batch_normalization_2 (BatchNormalization)      (None, 32, 64, 128)                         512
#
#  re_lu_2 (ReLU)                                  (None, 32, 64, 128)                         0
#
#  global_average_pooling2d (GlobalAveragePooling2  (None, 128)                                0
#  D)
#
#  dropout (Dropout)                               (None, 128)                                 0
#
#  dense (Dense)                                   (None, 64)                                  8256
#
#  dropout_1 (Dropout)                             (None, 64)                                  0
#
#  dense_1 (Dense)                                 (None, 1)                                   65
#
# ==============================================================================================================
# Total params: 101,665
# Trainable params: 101,217
# Non-trainable params: 448
# ______________________________________________________________________________________________________________

# %%
history = model.fit(
    X_train_pca,
    y_train, 
    epochs=1000, 
    batch_size=32, 
    validation_data=(X_val_pca, y_val),
    callbacks=cb,
)
# Out:
# Epoch 1/1000
# 12/12 [==============================] - 19s 852ms/step - loss: 0.4941 - accuracy: 0.7374 - auc: 0.9000 - val_loss: 0.7013 - val_accuracy: 0.5000 - val_auc: 0.8111 - lr: 1.0000e-04
# Epoch 2/1000
# 12/12 [==============================] - 9s 728ms/step - loss: 0.2468 - accuracy: 0.8966 - auc: 0.9893 - val_loss: 0.7012 - val_accuracy: 0.5000 - val_auc: 0.5000 - lr: 1.0000e-04
# Epoch 3/1000
# 12/12 [==============================] - 8s 674ms/step - loss: 0.1753 - accuracy: 0.9358 - auc: 0.9985 - val_loss: 0.7010 - val_accuracy: 0.5000 - val_auc: 0.5000 - lr: 1.0000e-04
# Epoch 4/1000
# 12/12 [==============================] - 7s 600ms/step - loss: 0.1354 - accuracy: 0.9665 - auc: 1.0000 - val_loss: 0.7008 - val_accuracy: 0.5000 - val_auc: 0.5000 - lr: 1.0000e-04
# Epoch 5/1000
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0883 - accuracy: 0.9860 - auc: 1.0000 - val_loss: 0.7009 - val_accuracy: 0.5000 - val_auc: 0.5000 - lr: 1.0000e-04
# Epoch 6/1000
# 12/12 [==============================] - 6s 529ms/step - loss: 0.0727 - accuracy: 0.9916 - auc: 0.9995 - val_loss: 0.7023 - val_accuracy: 0.5000 - val_auc: 0.5000 - lr: 1.0000e-04
# Epoch 7/1000
# 12/12 [==============================] - 7s 536ms/step - loss: 0.0721 - accuracy: 0.9888 - auc: 1.0000 - val_loss: 0.7063 - val_accuracy: 0.5000 - val_auc: 0.5333 - lr: 1.0000e-04
# Epoch 8/1000
# 12/12 [==============================] - 6s 519ms/step - loss: 0.0556 - accuracy: 0.9916 - auc: 1.0000 - val_loss: 0.7150 - val_accuracy: 0.5000 - val_auc: 0.5444 - lr: 1.0000e-04
# Epoch 9/1000
# 12/12 [==============================] - 6s 518ms/step - loss: 0.0560 - accuracy: 0.9804 - auc: 0.9998 - val_loss: 0.7256 - val_accuracy: 0.5000 - val_auc: 0.8333 - lr: 1.0000e-04
# Epoch 10/1000
# 12/12 [==============================] - 6s 529ms/step - loss: 0.0621 - accuracy: 0.9888 - auc: 0.9988 - val_loss: 0.7453 - val_accuracy: 0.5000 - val_auc: 0.9000 - lr: 1.0000e-04
# Epoch 11/1000
# 12/12 [==============================] - 6s 518ms/step - loss: 0.0526 - accuracy: 0.9944 - auc: 0.9981 - val_loss: 0.7782 - val_accuracy: 0.5000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 12/1000
# 12/12 [==============================] - 6s 508ms/step - loss: 0.0374 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.8170 - val_accuracy: 0.5000 - val_auc: 0.8667 - lr: 1.0000e-04
# Epoch 13/1000
# 12/12 [==============================] - 6s 518ms/step - loss: 0.0325 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.8599 - val_accuracy: 0.5000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 14/1000
# 12/12 [==============================] - 6s 535ms/step - loss: 0.0400 - accuracy: 0.9944 - auc: 0.9996 - val_loss: 0.9133 - val_accuracy: 0.5000 - val_auc: 0.9778 - lr: 1.0000e-04
# Epoch 15/1000
# 12/12 [==============================] - 6s 510ms/step - loss: 0.0424 - accuracy: 0.9916 - auc: 0.9988 - val_loss: 0.9819 - val_accuracy: 0.5000 - val_auc: 0.9000 - lr: 1.0000e-04
# Epoch 16/1000
# 12/12 [==============================] - 6s 537ms/step - loss: 0.0283 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 1.0551 - val_accuracy: 0.5000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 17/1000
# 12/12 [==============================] - 6s 528ms/step - loss: 0.0287 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 1.1316 - val_accuracy: 0.5000 - val_auc: 0.9778 - lr: 1.0000e-04
# Epoch 18/1000
# 12/12 [==============================] - 6s 519ms/step - loss: 0.0227 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 1.2085 - val_accuracy: 0.5000 - val_auc: 0.9111 - lr: 1.0000e-04
# Epoch 19/1000
# 12/12 [==============================] - 6s 528ms/step - loss: 0.0316 - accuracy: 0.9972 - auc: 0.9999 - val_loss: 1.3004 - val_accuracy: 0.5000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 20/1000
# 12/12 [==============================] - 6s 492ms/step - loss: 0.0428 - accuracy: 0.9804 - auc: 0.9998 - val_loss: 1.3855 - val_accuracy: 0.5000 - val_auc: 0.9889 - lr: 1.0000e-04
# Epoch 21/1000
# 12/12 [==============================] - 6s 500ms/step - loss: 0.0193 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 1.4745 - val_accuracy: 0.5000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 22/1000
# 12/12 [==============================] - 6s 510ms/step - loss: 0.0362 - accuracy: 0.9944 - auc: 0.9999 - val_loss: 1.5578 - val_accuracy: 0.5000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch
- accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 258/1000
# 12/12 [==============================] - 6s 504ms/step - loss: 0.0064 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 259/1000
# 12/12 [==============================] - 6s 510ms/step - loss: 0.0065 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 260/1000
# 12/12 [==============================] - 6s 500ms/step - loss: 0.0068 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 261/1000
# 12/12 [==============================] - 6s 501ms/step - loss: 0.0064 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 262/1000
# 12/12 [==============================] - 6s 492ms/step - loss: 0.0073 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 263/1000
# 12/12 [==============================] - 6s 510ms/step - loss: 0.0065 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 264/1000
# 12/12 [==============================] - 6s 491ms/step - loss: 0.0168 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 265/1000
# 12/12 [==============================] - 6s 492ms/step - loss: 0.0064 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 266/1000
# 12/12 [==============================] - 6s 508ms/step - loss: 0.0076 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 267/1000
# 12/12 [==============================] - 6s 492ms/step - loss: 0.0071 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 268/1000
# 12/12 [==============================] - 6s 509ms/step - loss: 0.0068 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 269/1000
# 12/12 [==============================] - 6s 492ms/step - loss: 0.0065 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 270/1000
# 12/12 [==============================] - 6s 492ms/step - loss: 0.0066 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 271/1000
# 12/12 [==============================] - 6s 501ms/step - loss: 0.0064 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 272/1000
# 12/12 [==============================] - 6s 518ms/step - loss: 0.0063 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 273/1000
# 12/12 [==============================] - 6s 501ms/step - loss: 0.0064 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 274/1000
# 12/12 [==============================] - 6s 510ms/step - loss: 0.0063 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 275/1000
# 12/12 [==============================] - 6s 500ms/step - loss: 0.0063 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 276/1000
# 12/12 [==============================] - 6s 500ms/step - loss: 0.0064 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 277/1000
# 12/12 [==============================] - 6s 500ms/step - loss: 0.0064 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 278/1000
# 12/12 [==============================] - 6s 528ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 279/1000
# 12/12 [==============================] - 6s 519ms/step - loss: 0.0063 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 280/1000
# 12/12 [==============================] - 6s 536ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 281/1000
# 12/12 [==============================] - 6s 518ms/step - loss: 0.0063 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 282/1000
# 12/12 [==============================] - 6s 518ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 283/1000
# 12/12 [==============================] - 6s 519ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 284/1000
# 12/12 [==============================] - 6s 519ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 285/1000
# 12/12 [==============================] - 6s 510ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 286/1000
# 12/12 [==============================] - 6s 527ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 287/1000
# 12/12 [==============================] - 6s 537ms/step - loss: 0.0063 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 288/1000
# 12/12 [==============================] - 6s 519ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 289/1000
# 12/12 [==============================] - 6s 526ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 290/1000
# 12/12 [==============================] - 6s 527ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 291/1000
# 12/12 [==============================] - 6s 519ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 292/1000
# 12/12 [==============================] - 6s 527ms/step - loss: 0.0065 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 293/1000
# 12/12 [==============================] - 6s 546ms/step - loss: 0.0065 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 294/1000
# 12/12 [==============================] - 6s 519ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 295/1000
# 12/12 [==============================] - 6s 500ms/step - loss: 0.0064 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 296/1000
# 12/12 [==============================] - 6s 509ms/step - loss: 0.0061 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 297/1000
# 12/12 [==============================] - 6s 519ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 298/1000
# 12/12 [==============================] - 6s 509ms/step - loss: 0.0061 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 299/1000
# 12/12 [==============================] - 6s 510ms/step - loss: 0.0061 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 300/1000
# 12/12 [==============================] - 6s 510ms/step - loss: 0.0061 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 301/1000
# 12/12 [==============================] - 6s 512ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 302/1000
# 12/12 [==============================] - 6s 509ms/step - loss: 0.0061 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 303/1000
# 12/12 [==============================] - 6s 501ms/step - loss: 0.0060 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 304/1000
# 12/12 [==============================] - 6s 518ms/step - loss: 0.0060 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 305/1000
# 12/12 [==============================] - 6s 510ms/step - loss: 0.0063 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 306/1000
# 12/12 [==============================] - 6s 500ms/step - loss: 0.0059 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 307/1000
# 12/12 [==============================] - 6s 499ms/step - loss: 0.0060 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 308/1000
# 12/12 [==============================] - 6s 492ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 309/1000
# 12/12 [==============================] - 6s 508ms/step - loss: 0.0061 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 310/1000
# 12/12 [==============================] - 6s 509ms/step - loss: 0.0059 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 311/1000
# 12/12 [==============================] - 6s 531ms/step - loss: 0.0061 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04

# %%
test_loss, test_acc, test_auc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 12/12 [==============================] - 3s 135ms/step - loss: 4.7302 - accuracy: 0.5000 - auc: 0.5000
# Test accuracy: 0.5000

# %%
model.save("/mnt/lustre/scratch/nlsas/home/csic/eoy/ioj/SkyNeuralNets/data/CNN_PCA_EE_model.h5")

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["accuracy"], label="training")
plt.plot(history.history["val_accuracy"], label="validation")
plt.yscale("log")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.xlim(-0.5, len(history.history["accuracy"]))
plt.savefig(f"{plots_directory}Accuracy_CNN_PCA_EE.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["loss"], label="training")
plt.plot(history.history["val_loss"], label="validation")
plt.yscale("log")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.xlim(-0.5, len(history.history["loss"]))
plt.savefig(f"{plots_directory}Loss_CNN_PCA_EE.png", dpi=300)
plt.show()

# %%
#Sanity check
print(np.mean(X_train_pca), np.std(X_train_pca))   #mean~0, st.dev~1
print(np.mean(X_test_pca),  np.std(X_test_pca))    #should be close to train
# Out:
# 1.3459724e-05 0.0012783312
# 1.3459724e-05 0.0012783312

# %%
#Get model probabilities
probs = model.predict(X_test_pca, batch_size=64).ravel()
# Out:
# 6/6 [==============================] - 3s 219ms/step

# %%
#Check the class balance, do we have a 50/50 split?
print("class balance test:", (y_test==1).mean())
# Out:
# class balance test: 0.5

# %%
#Let's check the ranges of probabilities, why is the CNN classfiying everything as LCDM?
print("min/max/mean probs:", probs.min(), probs.max(), probs.mean())
# Out:
# min/max/mean probs: 0.6925247 0.70217234 0.6949051

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix, accuracy_score, ConfusionMatrixDisplay

#Find optimal threshold from ROC
fpr, tpr, thr = roc_curve(y_test, probs)
t_opt = thr[np.argmax(tpr - fpr)]
print("AUC:", auc(fpr, tpr), "t*:", t_opt)

#Apply the new threshold to get predictions, Youden's index https://en.wikipedia.org/wiki/Youden%27s_J_statistic
pred = (probs >= t_opt).astype(int)
# Out:
# AUC: 1.0 t*: 0.69345516

# %%
#Accuracy
acc = accuracy_score(y_test, pred)
print("Accuracy:", acc)

#Confusion matrix
cm = confusion_matrix(y_test, pred, labels=[0, 1])
print("Confusion matrix:\n", cm)
# Out:
# Accuracy: 1.0
# Confusion matrix:
#  [[179   0]
#  [  0 179]]

# %%
#-----------------------------------------------------------------------------------------------------------
#Performance: correct & incorrect  predictions
#-----------------------------------------------------------------------------------------------------------
#True positive: LCDM=0, Feature=1
true_LCDM = []
true_MoG = []
false_LCDM = []
false_MoG = []

for pred, true in zip(pred, y_test):
    if pred==0 and true==0:
        true_LCDM.append(1)
    if pred==1 and true==1:
        true_MoG.append(1)
    if pred==0 and true==1:
        false_LCDM.append(1)
    if pred==1 and true==0:
        false_MoG.append(1)
lenghts=[len(true_LCDM),len(true_MoG),len(false_LCDM),len(false_MoG)]

print('     ','LCDM','FT')
print('True ',len(true_LCDM)/sum(lenghts),len(true_MoG)/sum(lenghts))
print('False',len(false_LCDM)/sum(lenghts),len(false_MoG)/sum(lenghts))
print('--------------')
print("Correct prediction: ",(len(true_LCDM)+len(true_MoG))/sum(lenghts))
print("Wrong prediction  : ",(len(false_LCDM)+len(false_MoG))/sum(lenghts))
# Out:
#       LCDM FT
# True  0.5 0.5
# False 0.0 0.0
# --------------
# Correct prediction:  1.0
# Wrong prediction  :  0.0

# %%
#Plot confusion matrix
fsize = 16
cm_prob = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
disp = ConfusionMatrixDisplay(confusion_matrix=cm_prob, display_labels=["ΛCDM", "Feature"])
fig, ax = plt.subplots(figsize=(6, 5))
disp.plot(
    cmap="Oranges",
    values_format=".1f",
    ax=ax,
    colorbar=True
)

ax.set_xlabel("Predicted label", fontsize=fsize)
ax.set_ylabel("True label", fontsize=fsize)
ax.tick_params(axis='both', labelsize=fsize) 

for text in ax.texts:
    text.set_fontsize(fsize)

cbar = ax.figure.axes[-1] 
cbar.tick_params(labelsize=fsize)

pos = cbar.get_position()

cbar.set_position([
    pos.x0,         # keep x position
    pos.y0 + 0.01,  # slightly raise it
    pos.width,      
    pos.height * 0.97   # <-- shrink to 70% height
])

plt.savefig(f"{plots_directory}confusion_matrix_CNN_EE_PCA_EE.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
#Plot the ROC curve with Youden index (https://en.wikipedia.org/wiki/Youden%27s_J_statistic#/media/File:ROC_Curve_T1D_Validation,_top5_r2filtered.svg)
from sklearn.metrics import auc
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, color="blue", lw=2, label=f"ROC curve (AUC = {roc_auc:.3f})")
plt.plot([0, 1], [0, 1], color="gray", lw=1, linestyle="--")

t_star_idx = np.argmax(tpr - fpr)
t_star = thr[t_star_idx]

#Mark t* point
plt.scatter(fpr[t_star_idx], tpr[t_star_idx], color="red", s=80, zorder=5,
            label=f"t* = {t_star:.4f}")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC)")
plt.legend(loc="lower right")
plt.grid(True)
plt.savefig(f"{plots_directory}ROC_CNN_PCA_EE.png", dpi=300)
plt.show()
