# %%
import healpy as hp
import numpy as np
import tensorflow as tf, sys, os
from tensorflow.keras import layers, models, regularizers
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.ndimage import gaussian_filter
tf.keras.backend.clear_session() #clear any previous models

plots_directory = "/mnt/lustre/scratch/nlsas/home/csic/eoy/ioj/SkyNeuralNets/plots/"
data_directory = "/mnt/lustre/scratch/nlsas/home/csic/eoy/ioj/SkySimulation/data/simulated_data/"
os.chdir(data_directory)
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1' #disable GPU
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  #suppress TF warnings
print("Current working directory:", os.getcwd())
# Out:
# 2025-12-05 15:21:00.407883: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-05 15:21:26.553137: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-05 15:21:33.007805: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /mnt/netapp1/Optcesga_FT2_RHEL7/2020/gentoo/22072020/usr/gr/lib64
# 2025-12-05 15:21:33.007837: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2025-12-05 15:21:35.784392: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-05 15:22:17.558160: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /mnt/netapp1/Optcesga_FT2_RHEL7/2020/gentoo/22072020/usr/gr/lib64
# 2025-12-05 15:22:17.558766: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /mnt/netapp1/Optcesga_FT2_RHEL7/2020/gentoo/22072020/usr/gr/lib64
# 2025-12-05 15:22:17.558776: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Current working directory: /mnt/lustre/scratch/nlsas/home/csic/eoy/ioj/SkySimulation/data/simulated_data

# %%
print("TF:", tf.__version__)
print("Python:", sys.version.split()[0])
print("LD_LIBRARY_PATH:", os.environ.get("LD_LIBRARY_PATH"))
# Out:
# TF: 2.10.1
# Python: 3.10.15
# LD_LIBRARY_PATH: /mnt/netapp1/Optcesga_FT2_RHEL7/2020/gentoo/22072020/usr/gr/lib64

# %%
from SkyNeuralNets import read_map
#Read the data
path_lcdm = "./simulated_maps/"
map_temp_data = read_map(path_lcdm + 'cmb_map_0.fits')

#Visualize the map
nside = hp.npix2nside(len(map_temp_data))
#nside = 64
print(f"NSIDE: {nside}")
# Out:
# Filename: ./simulated_maps/cmb_map_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# NSIDE: 256

# %%
def read_all_maps(path_lcdm, path_feature, n_maps=100):
    maps = []
    labels = []
    
    #LCDM maps
    for i in range(n_maps):
        map_lcdm = read_map(f"{path_lcdm}cmb_map_{i}.fits")
        maps.append(map_lcdm)
        labels.append(0)  #lcdm
    
    #Feature maps
    for i in range(n_maps):
        map_feature = read_map(f"{path_feature}cmb_map_feature_{i}.fits")
        maps.append(map_feature)
        labels.append(1)  #feature
    
    maps = np.array(maps).astype(np.float32)[..., None]  #Add channel dimension
    labels = np.array(labels).astype(np.int32)
    #print(labels)
    return maps, labels

# %%
def map_to_image(hp_map, xsize=256):
    #Validate that map has correct length
    hp_map = np.asarray(hp_map, dtype=np.float64)
    try:
        nside = hp.get_nside(hp_map)
    except Exception as e:
        print("Invalid map shape:", hp_map.shape)
        raise e
    img = hp.cartview(hp_map, xsize=xsize, return_projected_map=True, title="", cbar=False)
    plt.close()
    return img

# %%
path_feature = "./simulated_maps/"
x_raw, y_raw = read_all_maps(path_lcdm, path_feature, n_maps=225) #0: lcdm, 1:feature
# Out:
# Filename: ./simulated_maps/cmb_map_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_12.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_13.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_14.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_15.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_18.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_19.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_20.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_21.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_22.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_23.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_24.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_25.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_26.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_27.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_28.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_29.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_30.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_31.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_32.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_33.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_34.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_35.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_36.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_37.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_38.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_39.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_40.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_41.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_42.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_43.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_44.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_45.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_46.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_47.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_48.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_49.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_50.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_51.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_52.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_53.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_54.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_55.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_56.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_57.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_58.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_59.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_60.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_61.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_62.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_63.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_64.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_65.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_66.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_67.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_68.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_69.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_70.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_71.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_72.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_73.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_74.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_75.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_76.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_77.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_78.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_79.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_80.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_81.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_82.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_83.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_84.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_85.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_86.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_87.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_88.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_89.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_90.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_91.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_92.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_93.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_94.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_95.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_96.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_97.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_98.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_99.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_100.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_101.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_102.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_103.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_104.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_105.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_106.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_107.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_108.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_109.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_110.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_111.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_112.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_113.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_114.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_115.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_116.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_117.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_118.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_119.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_120.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_121.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_122.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_123.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_124.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_125.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_126.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_127.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_128.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_129.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_130.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_131.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_132.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_133.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_134.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_135.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_136.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_137.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_138.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_139.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_140.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_141.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_142.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_143.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_144.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_145.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_146.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_147.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_148.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_149.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_150.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_151.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_152.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_153.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_154.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_155.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_156.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_157.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_158.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_159.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_160.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_161.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_162.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_163.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_164.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_165.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_166.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_167.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_168.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_169.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_170.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_171.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_172.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_173.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_174.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_175.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_176.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_177.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_178.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_179.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_180.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
# ...
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_167.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_168.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_169.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_170.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_171.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_172.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_173.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_174.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_175.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_176.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_177.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_178.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_179.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_180.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_181.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_182.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_183.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_184.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_185.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_186.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_187.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_188.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_189.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_190.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_191.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_192.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_193.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_194.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_195.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_196.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_197.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_198.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_199.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_200.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_201.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_202.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_203.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_204.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_205.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_206.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_207.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_208.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_209.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_210.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_211.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_212.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_213.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_214.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_215.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_216.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_217.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_218.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_219.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_220.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_221.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_222.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_223.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/cmb_map_feature_224.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   768R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )

# %%
def map_to_image(hp_map, xsize=256):
    """ Converts a Healpy map to a 2D image.
    Args:
        hp_map (np.ndarray): The Healpy map to convert.
        xsize (int): The size of the output image.
    Returns:
        np.ndarray: The 2D image representation of the Healpy map.
    Raises:
        Exception: If the map shape is invalid.
    """

    #Validate that the map has correct length
    hp_map = np.asarray(hp_map, dtype=np.float64)
    try:
        nside = hp.get_nside(hp_map)
    except Exception as e:
        print("Invalid map shape:", hp_map.shape)
        raise e
    img = hp.cartview(hp_map, xsize=xsize, return_projected_map=True, title="", cbar=False)
    plt.close()
    return img

# %%
x_raw_new = np.array(x_raw).squeeze()

# %%
imgs = np.array([map_to_image(m) for m in x_raw_new])
if imgs.ndim == 3:
    imgs = imgs[..., np.newaxis]  #add channel dimension

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(imgs, y_raw, test_size=0.2, random_state=15)
X_test, X_val, y_test, y_val = train_test_split(imgs, y_raw, test_size=0.2, random_state=15)

# %%
np.shape(X_train)
# Out:
# (360, 128, 256, 1)

# %%
#Check the class weights to handle imbalance
from sklearn.utils import class_weight
print(f"Training set Class 1 ratio: {y_train.mean():.4f}")
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(y_train),
    y=y_train
)
# Out:
# Training set Class 1 ratio: 0.4889

# %%
# ---- 1. Flatten data ----
orig_shape = X_train.shape[1:]   # e.g. (H, W, 1) or (H, W)
n_features = np.prod(orig_shape)

X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat   = X_val.reshape(X_val.shape[0], -1)
X_test_flat  = X_test.reshape(X_test.shape[0], -1)

# ---- 2. Fit PCA on noise (Class 0 in TRAIN only) ----
n_components = 100  # or 0.999 if you want variance fraction

noise_indices = (y_train == 0)
X_noise_flat  = X_train_flat[noise_indices]

if X_noise_flat.shape[0] == 0:
    raise RuntimeError("No Class 0 maps in y_train, cannot fit PCA")

print("Fitting PCA on noise maps...")
pca = PCA(n_components=n_components, whiten=False)
pca.fit(X_noise_flat)

print(f"Explained variance: {np.sum(pca.explained_variance_ratio_):.4f}")

# ---- 3. Subtract noise from all datasets ----
def subtract_noise(X_flat, pca_obj):
    noise_part = pca_obj.inverse_transform(pca_obj.transform(X_flat))
    signal_part = X_flat - noise_part
    return noise_part, signal_part

X_train_noise_flat, X_train_signal_flat = subtract_noise(X_train_flat, pca)
X_val_noise_flat,   X_val_signal_flat   = subtract_noise(X_val_flat,   pca)
X_test_noise_flat,  X_test_signal_flat  = subtract_noise(X_test_flat,  pca)

# Reshape back
X_train_pca = X_train_signal_flat.reshape(X_train.shape).astype(np.float32)
X_val_pca   = X_val_signal_flat.reshape(X_val.shape).astype(np.float32)
X_test_pca  = X_test_signal_flat.reshape(X_test.shape).astype(np.float32)

print("PCA noise subtraction done.")
# Out:
# Fitting PCA on noise maps...
# Explained variance: 1.0000
# PCA noise subtraction done.

# %%
#Check the statistics of the subtracted signal
print("Original Stats:  Mean={:.5f}, Std={:.5f}".format(np.mean(X_train), np.std(X_train)))
print("Signal Stats:    Mean={:.5e}, Std={:.5e}".format(np.mean(X_train_pca), np.std(X_train_pca)))
# Out:
# Original Stats:  Mean=-1.84362, Std=101.69793
# Signal Stats:    Mean=6.73673e-05, Std=7.27392e-03

# %%
#======== Define Model ========
model = models.Sequential([
    layers.Input(shape=X_train.shape[1:]),        

    layers.Conv2D(32, (3,3), padding="same", use_bias=False),
    layers.BatchNormalization(), layers.ReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), padding="same", use_bias=False),
    layers.BatchNormalization(), layers.ReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), padding="same", use_bias=False),
    layers.BatchNormalization(), layers.ReLU(),

    layers.GlobalAveragePooling2D(),             
    layers.Dropout(0.2),
    layers.Dense(64, activation="relu",
                 kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.2),
    layers.Dense(1, activation="sigmoid"),
])
# Out:
# 2025-12-05 16:09:35.562759: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /mnt/netapp1/Optcesga_FT2_RHEL7/2020/gentoo/22072020/usr/gr/lib64
# 2025-12-05 16:09:35.628093: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-05 16:09:35.682960: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (login210-18): /proc/driver/nvidia/version does not exist
# 2025-12-05 16:09:36.485132: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4, clipnorm=1.0),
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)
model.summary(110)

cb = [
  tf.keras.callbacks.EarlyStopping(monitor="val_auc", patience=500, mode="max", restore_best_weights=True),
  tf.keras.callbacks.ReduceLROnPlateau(monitor="val_auc", factor=0.5, patience=500, mode="max", min_lr=1e-6)
]
# Out:
# Model: "sequential"
# ______________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                                Param #
# ==============================================================================================================
#  conv2d (Conv2D)                                 (None, 128, 256, 32)                        288
#
#  batch_normalization (BatchNormalization)        (None, 128, 256, 32)                        128
#
#  re_lu (ReLU)                                    (None, 128, 256, 32)                        0
#
#  max_pooling2d (MaxPooling2D)                    (None, 64, 128, 32)                         0
#
#  conv2d_1 (Conv2D)                               (None, 64, 128, 64)                         18432
#
#  batch_normalization_1 (BatchNormalization)      (None, 64, 128, 64)                         256
#
#  re_lu_1 (ReLU)                                  (None, 64, 128, 64)                         0
#
#  max_pooling2d_1 (MaxPooling2D)                  (None, 32, 64, 64)                          0
#
#  conv2d_2 (Conv2D)                               (None, 32, 64, 128)                         73728
#
#  batch_normalization_2 (BatchNormalization)      (None, 32, 64, 128)                         512
#
#  re_lu_2 (ReLU)                                  (None, 32, 64, 128)                         0
#
#  global_average_pooling2d (GlobalAveragePooling2  (None, 128)                                0
#  D)
#
#  dropout (Dropout)                               (None, 128)                                 0
#
#  dense (Dense)                                   (None, 64)                                  8256
#
#  dropout_1 (Dropout)                             (None, 64)                                  0
#
#  dense_1 (Dense)                                 (None, 1)                                   65
#
# ==============================================================================================================
# Total params: 101,665
# Trainable params: 101,217
# Non-trainable params: 448
# ______________________________________________________________________________________________________________

# %%
history = model.fit(
    X_train_pca,
    y_train, 
    epochs=1000, 
    batch_size=32, 
    validation_data=(X_val_pca, y_val),
    callbacks=cb,
)
# Out:
# Epoch 1/1000
# 12/12 [==============================] - 19s 863ms/step - loss: 0.3958 - accuracy: 0.8722 - auc: 0.9574 - val_loss: 0.7025 - val_accuracy: 0.4556 - val_auc: 0.5408 - lr: 1.0000e-04
# Epoch 2/1000
# 12/12 [==============================] - 7s 599ms/step - loss: 0.2168 - accuracy: 0.9611 - auc: 0.9920 - val_loss: 0.7074 - val_accuracy: 0.4556 - val_auc: 0.7959 - lr: 1.0000e-04
# Epoch 3/1000
# 12/12 [==============================] - 7s 603ms/step - loss: 0.1524 - accuracy: 0.9722 - auc: 0.9994 - val_loss: 0.7121 - val_accuracy: 0.4556 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0050 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 479/1000
# 12/12 [==============================] - 7s 556ms/step - loss: 0.0050 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 480/1000
# 12/12 [==============================] - 6s 537ms/step - loss: 0.0050 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 481/1000
# 12/12 [==============================] - 6s 545ms/step - loss: 0.0049 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 482/1000
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0049 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 483/1000
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0050 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 484/1000
# 12/12 [==============================] - 6s 527ms/step - loss: 0.0049 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 485/1000
# 12/12 [==============================] - 7s 554ms/step - loss: 0.0049 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 486/1000
# 12/12 [==============================] - 7s 556ms/step - loss: 0.0049 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 487/1000
# 12/12 [==============================] - 7s 546ms/step - loss: 0.0050 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 488/1000
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0048 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 489/1000
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0049 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 490/1000
# 12/12 [==============================] - 7s 564ms/step - loss: 0.0048 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 491/1000
# 12/12 [==============================] - 6s 528ms/step - loss: 0.0094 - accuracy: 0.9972 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 492/1000
# 12/12 [==============================] - 7s 574ms/step - loss: 0.0103 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 493/1000
# 12/12 [==============================] - 7s 555ms/step - loss: 0.0053 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 494/1000
# 12/12 [==============================] - 7s 591ms/step - loss: 0.0054 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 495/1000
# 12/12 [==============================] - 6s 537ms/step - loss: 0.0051 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 496/1000
# 12/12 [==============================] - 7s 544ms/step - loss: 0.0054 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 497/1000
# 12/12 [==============================] - 7s 552ms/step - loss: 0.0050 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 498/1000
# 12/12 [==============================] - 6s 529ms/step - loss: 0.0048 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 499/1000
# 12/12 [==============================] - 7s 582ms/step - loss: 0.0049 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 500/1000
# 12/12 [==============================] - 7s 546ms/step - loss: 0.0049 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 501/1000
# 12/12 [==============================] - 6s 528ms/step - loss: 0.0048 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 502/1000
# 12/12 [==============================] - 7s 545ms/step - loss: 0.0049 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 503/1000
# 12/12 [==============================] - 7s 584ms/step - loss: 0.0048 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04

# %%
test_loss, test_acc, test_auc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 12/12 [==============================] - 2s 118ms/step - loss: 17.5083 - accuracy: 0.4889 - auc: 0.5000
# Test accuracy: 0.4889

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["accuracy"], label="training")
plt.plot(history.history["val_accuracy"], label="validation")
plt.yscale("log")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.xlim(-0.5, len(history.history["accuracy"]))
plt.savefig(f"{plots_directory}Accuracy_CNN_PCA.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["loss"], label="training")
plt.plot(history.history["val_loss"], label="validation")
plt.yscale("log")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.xlim(-0.5, len(history.history["loss"]))
plt.savefig(f"{plots_directory}Loss_CNN_PCA.png", dpi=300)
plt.show()

# %%
#Sanity check
print(np.mean(X_train_pca), np.std(X_train_pca))   #mean~0, st.dev~1
print(np.mean(X_test_pca),  np.std(X_test_pca))    #should be close to train
# Out:
# 6.736732e-05 0.007273919
# 6.736732e-05 0.007273919

# %%
#Get model probabilities
probs = model.predict(X_test_pca, batch_size=64).ravel()
# Out:
# 6/6 [==============================] - 4s 220ms/step

# %%
#Check the class balance, do we have a 50/50 split?
print("class balance test:", (y_test==1).mean())
# Out:
# class balance test: 0.4888888888888889

# %%
#Let's check the ranges of probabilities, why is the CNN classfiying everything as LCDM?
print("min/max/mean probs:", probs.min(), probs.max(), probs.mean())
# Out:
# min/max/mean probs: 0.4464353 0.45519155 0.44829

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix, accuracy_score, ConfusionMatrixDisplay

#Find optimal threshold from ROC
fpr, tpr, thr = roc_curve(y_test, probs)
t_opt = thr[np.argmax(tpr - fpr)]
print("AUC:", auc(fpr, tpr), "t*:", t_opt)

#Apply the new threshold to get predictions, Youden's index https://en.wikipedia.org/wiki/Youden%27s_J_statistic
pred = (probs >= t_opt).astype(int)
# Out:
# AUC: 1.0 t*: 0.4471154

# %%
#Accuracy
acc = accuracy_score(y_test, pred)
print("Accuracy:", acc)

#Confusion matrix
cm = confusion_matrix(y_test, pred, labels=[0, 1])
print("Confusion matrix:\n", cm)
# Out:
# Accuracy: 1.0
# Confusion matrix:
#  [[184   0]
#  [  0 176]]

# %%
#-----------------------------------------------------------------------------------------------------------
#Performance: correct & incorrect  predictions
#-----------------------------------------------------------------------------------------------------------
#True positive: LCDM=0, Feature=1
true_LCDM = []
true_MoG = []
false_LCDM = []
false_MoG = []

for pred, true in zip(pred, y_test):
    if pred==0 and true==0:
        true_LCDM.append(1)
    if pred==1 and true==1:
        true_MoG.append(1)
    if pred==0 and true==1:
        false_LCDM.append(1)
    if pred==1 and true==0:
        false_MoG.append(1)
lenghts=[len(true_LCDM),len(true_MoG),len(false_LCDM),len(false_MoG)]

print('     ','LCDM','FT')
print('True ',len(true_LCDM)/sum(lenghts),len(true_MoG)/sum(lenghts))
print('False',len(false_LCDM)/sum(lenghts),len(false_MoG)/sum(lenghts))
print('--------------')
print("Correct prediction: ",(len(true_LCDM)+len(true_MoG))/sum(lenghts))
print("Wrong prediction  : ",(len(false_LCDM)+len(false_MoG))/sum(lenghts))
# Out:
#       LCDM FT
# True  0.5111111111111111 0.4888888888888889
# False 0.0 0.0
# --------------
# Correct prediction:  1.0
# Wrong prediction  :  0.0

# %%
#Plot confusion matrix
cm_prob = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
disp = ConfusionMatrixDisplay(confusion_matrix=cm_prob, display_labels=["ΛCDM", "Feature"])
fig, ax = plt.subplots(figsize=(6, 5))
disp.plot(
    cmap="Blues",
    values_format=".1f",
    ax=ax,
    colorbar=True
)

ax.set_xlabel("Predicted label", fontsize=fsize)
ax.set_ylabel("True label", fontsize=fsize)
ax.tick_params(axis='both', labelsize=fsize) 

for text in ax.texts:
    text.set_fontsize(fsize)

cbar = ax.figure.axes[-1] 
cbar.tick_params(labelsize=fsize)

pos = cbar.get_position()

cbar.set_position([
    pos.x0,         # keep x position
    pos.y0 + 0.01,  # slightly raise it
    pos.width,      
    pos.height * 0.97   # <-- shrink to 70% height
])

plt.tight_layout()
plt.savefig(f"{plots_directory}confusion_matrix_CNN_PCA.pdf", dpi=300)
plt.show()

# %%
#Plot the ROC curve with Youden index (https://en.wikipedia.org/wiki/Youden%27s_J_statistic#/media/File:ROC_Curve_T1D_Validation,_top5_r2filtered.svg)
from sklearn.metrics import auc
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, color="blue", lw=2, label=f"ROC curve (AUC = {roc_auc:.3f})")
plt.plot([0, 1], [0, 1], color="gray", lw=1, linestyle="--")

t_star_idx = np.argmax(tpr - fpr)
t_star = thr[t_star_idx]

#Mark t* point
plt.scatter(fpr[t_star_idx], tpr[t_star_idx], color="red", s=80, zorder=5,
            label=f"t* = {t_star:.4f}")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC)")
plt.legend(loc="lower right")
plt.grid(True)
plt.savefig(f"{plots_directory}ROC_CNN_PCA.png", dpi=300)
plt.show()
